# %% [markdown]
# # Dependences and imports

# %%
# %%bash
#
# # install required system dependencies
# apt-get install -y xvfb x11-utils
#
# # install required python dependencies (might need to install additional gym extras depending)
# pip install -q pyvirtualdisplay PyOpenGL PyOpenGL-accelerate gymnasium==0.29.0
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.15).
# The following additional packages will be installed:
#   libxtst6 libxxf86dga1
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   libxtst6 libxxf86dga1 x11-utils
# 0 upgraded, 3 newly installed, 0 to remove and 38 not upgraded.
# Need to get 232 kB of archives.
# After this operation, 819 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Fetched 232 kB in 0s (1,923 kB/s)
# Selecting previously unselected package libxtst6:amd64.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up x11-utils (7.7+5build2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.8/953.8 kB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 70.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.

# %%
import base64
import glob
import io

import gymnasium as gym
import matplotlib.pyplot  as plt
import numpy as np
from gymnasium.wrappers.record_video import RecordVideo
from IPython.display import HTML
from IPython import display as ipythondisplay
from tqdm.notebook import tqdm

# %% [markdown]
# # ideia

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Display utils

# %%
VIDEO_FOLDER = './video/'

# %%
def show_video():
    mp4list = glob.glob(f'{VIDEO_FOLDER}/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")


def wrap_env(env):
    env = RecordVideo(env, VIDEO_FOLDER,
                      episode_trigger=lambda episode_number: True)
    return env

# %% [markdown]
# # Base simulation

# %%
env = wrap_env(gym.make("Taxi-v3", render_mode="rgb_array"))

def base_simulation(env):
    observation = env.reset()

    while True:

        env.render()

        action = env.action_space.sample()

        observation, reward, done, truncated, info = env.step(action)

        if done or truncated:
            break

    env.close()

    show_video()

base_simulation(env)
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/core.py:297: UserWarning: WARN: env.is_vector_env to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.is_vector_env` for environment variables or `env.get_attr('is_vector_env')` that will search the reminding wrappers.
#   logger.warn(
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-0.mp4
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# @markdown <h1>Setting the hyperparameters for Q-learning Taxi</h1>
alpha = 0.8 # @param {type:"slider", min: 0.0, max:1.0, step: 0.01}
discount_factor = 0.1  # @param {type:"slider", min: 0.0, max:1.0, step: 0.01}
train_episodes = 1000  # @param {type:"integer"}
max_steps = 100  # @param {type:"integer"}
min_epsilon = 0.05  # @param {type:"number"}
max_epsilon = 1  # @param {type:"integer"}
epsilon_decay = 0.021   # @param {type:"slider", min: 0.0, max:1.0, step: 0.001}
eval_episodes=10  # @param {type:"integer"}

env = gym.make("Taxi-v3", render_mode="rgb_array")


def q_learning(env, train_episodes = 1000, decay = 0.01, max_steps = 100,
               eval_episodes=10, min_epsilon = 0.05, debug=False):
    Q = np.zeros((env.observation_space.n, env.action_space.n))

    epsilon = 1
    training_rewards = []
    epsilons = []

    for episode in tqdm(range(train_episodes)):
        state, _ = env.reset()
        total_training_rewards = 0

        for step in range(max_steps):
            roulette = np.random.uniform(0, 1)

            action = (np.argmax(Q[state,:]) if roulette > epsilon  # exploit
                      else env.action_space.sample())  # explore

            new_state, reward, done, truncated, info = env.step(action)

            if debug and reward != 0.1:
                print(reward)

            Q[state, action] = (
                (1-alpha) * Q[state, action] +
                alpha  * (reward + discount_factor * Q[new_state, :].max())
            )

            total_training_rewards += reward
            state = new_state

            if done or truncated:
                break

        epsilon = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay*episode)

        training_rewards.append(total_training_rewards)
        epsilons.append(epsilon)

        if episode % eval_episodes == 0:
            try:
                print(f"Episode {episode:>3}: Accumulated reward: {np.mean(training_rewards[-10:]): 10.2f}")
            except:
                pass

    return Q, training_rewards, epsilons


Q, training_rewards, epsilons = q_learning(
    env, train_episodes, epsilon_decay, max_steps,
    eval_episodes, min_epsilon, debug=False
)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Episode   0: Accumulated reward:    -397.00
# Episode  10: Accumulated reward:    -336.20
# Episode  20: Accumulated reward:    -352.30
# Episode  30: Accumulated reward:    -318.70
# Episode  40: Accumulated reward:    -270.60
# Episode  50: Accumulated reward:    -267.40
# Episode  60: Accumulated reward:    -191.30
# Episode  70: Accumulated reward:    -218.50
# Episode  80: Accumulated reward:    -192.70
# Episode  90: Accumulated reward:    -177.10
# Episode 100: Accumulated reward:    -145.80
# Episode 110: Accumulated reward:    -133.20
# Episode 120: Accumulated reward:    -140.10
# Episode 130: Accumulated reward:    -125.60
# Episode 140: Accumulated reward:    -100.00
# Episode 150: Accumulated reward:     -88.50
# Episode 160: Accumulated reward:    -109.60
# Episode 170: Accumulated reward:     -95.90
# Episode 180: Accumulated reward:     -93.10
# Episode 190: Accumulated reward:     -74.80
# Episode 200: Accumulated reward:     -87.90
# Episode 210: Accumulated reward:     -78.40
# Episode 220: Accumulated reward:     -58.50
# Episode 230: Accumulated reward:     -58.90
# Episode 240: Accumulated reward:     -66.40
# Episode 250: Accumulated reward:     -58.20
# Episode 260: Accumulated reward:     -73.40
# Episode 270: Accumulated reward:     -50.50
# Episode 280: Accumulated reward:     -71.20
# Episode 290: Accumulated reward:     -62.50
# Episode 300: Accumulated reward:     -50.30
# Episode 310: Accumulated reward:     -35.30
# Episode 320: Accumulated reward:     -38.80
# Episode 330: Accumulated reward:     -16.60
# Episode 340: Accumulated reward:     -45.60
# Episode 350: Accumulated reward:     -17.50
# Episode 360: Accumulated reward:     -28.30
# Episode 370: Accumulated reward:     -15.50
# Episode 380: Accumulated reward:      -7.70
# Episode 390: Accumulated reward:     -23.70
# Episode 400: Accumulated reward:     -15.90
# Episode 410: Accumulated reward:      -8.30
# Episode 420: Accumulated reward:      -4.70
# Episode 430: Accumulated reward:     -22.00
# Episode 440: Accumulated reward:     -14.40
# Episode 450: Accumulated reward:     -14.80
# Episode 460: Accumulated reward:     -14.70
# Episode 470: Accumulated reward:      -9.70
# Episode 480: Accumulated reward:     -11.10
# Episode 490: Accumulated reward:      -8.60
# Episode 500: Accumulated reward:     -19.40
# Episode 510: Accumulated reward:      -5.90
# Episode 520: Accumulated reward:       0.50
# Episode 530: Accumulated reward:      -6.00
# Episode 540: Accumulated reward:       2.70
# Episode 550: Accumulated reward:      -0.90
# Episode 560: Accumulated reward:      -1.50
# Episode 570: Accumulated reward:      -4.80
# Episode 580: Accumulated reward:      -7.50
# Episode 590: Accumulated reward:       2.50
# Episode 600: Accumulated reward:      -0.60
# Episode 610: Accumulated reward:      -4.10
# Episode 620: Accumulated reward:       1.00
# Episode 630: Accumulated reward:       2.30
# Episode 640: Accumulated reward:       3.30
# Episode 650: Accumulated reward:      -1.00
# Episode 660: Accumulated reward:       1.90
# Episode 670: Accumulated reward:       1.30
# Episode 680: Accumulated reward:       7.10
# Episode 690: Accumulated reward:       3.30
# Episode 700: Accumulated reward:       2.70
# Episode 710: Accumulated reward:      -2.10
# Episode 720: Accumulated reward:       6.30
# Episode 730: Accumulated reward:       6.50
# Episode 740: Accumulated reward:       1.90
# Episode 750: Accumulated reward:       5.40
# Episode 760: Accumulated reward:       0.80
# Episode 770: Accumulated reward:       6.40
# Episode 780: Accumulated reward:       6.00
# Episode 790: Accumulated reward:       1.50
# Episode 800: Accumulated reward:       6.30
# Episode 810: Accumulated reward:      -2.70
# Episode 820: Accumulated reward:       0.00
# Episode 830: Accumulated reward:       1.70
# Episode 840: Accumulated reward:       2.60
# Episode 850: Accumulated reward:      -0.50
# Episode 860: Accumulated reward:       6.90
# Episode 870: Accumulated reward:       2.40
# Episode 880: Accumulated reward:       2.30
# Episode 890: Accumulated reward:       4.90
# Episode 900: Accumulated reward:       5.30
# Episode 910: Accumulated reward:       0.10
# Episode 920: Accumulated reward:       1.70
# Episode 930: Accumulated reward:       4.40
# Episode 940: Accumulated reward:       4.10
# Episode 950: Accumulated reward:       5.50
# Episode 960: Accumulated reward:       4.60
# Episode 970: Accumulated reward:       5.20
# Episode 980: Accumulated reward:       1.40
# Episode 990: Accumulated reward:       4.20

# %%
Q.shape, Q

# %%
def plot(training_rewards, epsilons):
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
    ax1.plot(training_rewards)
    ax1.title.set_text('Reward for epsodes')
    plt.ylabel('Training total reward')

    ax2.plot(epsilons)
    ax2.title.set_text("Epsilon for episodes")
    plt.ylabel('Epsilon')
    plt.xlabel('Episode')
    plt.show()


plot(training_rewards, epsilons)

# %%
env = wrap_env(gym.make("Taxi-v3", render_mode="rgb_array"))


def simulate_using_Q(env, Q, max_steps=100, debug=False):
    observation, _ = env.reset()

    for _ in range(max_steps):

        env.render()

        action = np.argmax(Q[observation,:])
        if debug:
            print(Q[observation,:])

        observation, reward, done, truncated, info = env.step(action)

        if done or truncated:
            break

    env.close()

    show_video()


simulate_using_Q(env, Q)
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /content/video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/core.py:297: UserWarning: WARN: env.is_vector_env to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.is_vector_env` for environment variables or `env.get_attr('is_vector_env')` that will search the reminding wrappers.
#   logger.warn(
# Moviepy - Building video /content/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-0.mp4
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# # Discrete Flappy-bird

# %%
# !pip install -q flappy-bird-gymnasium
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 40.5 MB/s eta 0:00:00

# %%
# @markdown <h1>code for flappy bird enviroment</h1>
import random
from itertools import cycle
from typing import Tuple, Optional

import gymnasium
import pygame
from flappy_bird_gymnasium import FlappyBirdEnv
from flappy_bird_gymnasium.envs.constants import (
    PLAYER_HEIGHT, PLAYER_WIDTH, PIPE_HEIGHT, PIPE_WIDTH, PLAYER_MAX_VEL_Y
)


# quantization = [-.8,-.5, -.3, -.2, -.1, -.05, -0.02, 0.02, .05, .1, .2, .3, .5, .8]
quantizations = {
    'v_dist': [-.15, -.05, 0, .05, .15, .3],
    'player_y': [.2, .6],
    'vel_y': [-.5, -.1, .2, .5],
    'h_dist': [.2]
}


def bound(val, lower=-1, upper=1):
    return max(min(val, upper), lower)

class FlappyBirdDiscreteEnv(FlappyBirdEnv):
    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 30}

    def __init__(
        self,
        screen_size: Tuple[int, int] = (288, 512),
        pipe_gap: int = 100,
        bird_color: str = "yellow",
        pipe_color: str = "green",
        render_mode: Optional[str] = None,
        background: Optional[str] = "day",
        score_limit: Optional[int] = None,
        debug: bool = False,
    ) -> None:
        super().__init__(screen_size, False, True, False,
                         pipe_gap, bird_color, pipe_color, render_mode, background, score_limit, debug)

        self.shape = (10, 20, 20)
        self.observation_space = gymnasium.spaces.Discrete(7 * 2)


    def _get_observation_features_raw(self):
        up_pipe = low_pipe = None
        h_dist = 0
        prev_dist = -100
        pipes = sorted(zip(self._upper_pipes, self._lower_pipes),
                       key=lambda x: x[0]["x"])

        for up_pipe, low_pipe in pipes:
            h_dist = (low_pipe["x"] + PIPE_WIDTH / 2
                      - (self._player_x - PLAYER_WIDTH / 2))
            h_dist += 5  # extra distance to compensate for the buggy hit-box
            if h_dist >= 0:
                break

            prev_dist = h_dist

        upper_pipe_y = up_pipe["y"] + PIPE_HEIGHT
        lower_pipe_y = low_pipe["y"]
        player_y = self._player_y
        vel_y = self._player_vel_y

        v_dist = (upper_pipe_y + lower_pipe_y) / 2 - (player_y
                                                      + PLAYER_HEIGHT/2)

        h_dist /= self._screen_width
        prev_dist /= self._screen_width

        v_dist /= self._screen_height
        vel_y /= PLAYER_MAX_VEL_Y
        lower_pipe_y /= self._screen_height
        upper_pipe_y /= self._screen_height
        player_y /= self._screen_height

        return prev_dist, h_dist, v_dist, vel_y, lower_pipe_y, upper_pipe_y, player_y

    def _get_observation_features(self):
        (prev_dist, h_dist, v_dist, vel_y,
        lower_pipe_y, upper_pipe_y, player_y) = self._get_observation_features_raw()

        v_dist = np.digitize(v_dist, bins=quantizations['v_dist'])  % 8
        player_y = np.digitize(player_y, bins=quantizations['player_y'])  % 4
        vel_y = np.digitize(vel_y, bins=quantizations['vel_y'])  % 5
        h_dist = np.digitize(h_dist, bins=quantizations['h_dist'])  % 3
        prev_dist = np.digitize(-prev_dist, bins=quantizations['h_dist'])  % 3

        factor = 1
        state = (
            v_dist +
            # player_y * (factor := factor * (len(quantizations['v_dist']) + 1)) +
            # vel_y *    (factor := factor * (len(quantizations['v_dist']) + 1)) +
            h_dist * (factor := factor * (len(quantizations['v_dist']) + 1))
            # 0 if player_y <= lower_pipe_y else (1 if lower_pipe_y <= player_y <= upper_pipe_y else 2)
            # int(bound(h_dist, 0) * 10) +
            # int((bound(v_dist, -0.5, 0.5) + 0.5) * 20) * self.shape[0]
            # int((bound(vel_y) + 1) * 10 * self.shape[0] * self.shape[1])
        )

        return state, None

    def reset(self, seed=None, options=None):
        """Resets the environment (starts a new game)."""
        super().reset(seed=seed)

        self._player_x = int(self._screen_width * .2)
        self._player_y = int((self._screen_height - PLAYER_HEIGHT) / 2)
        # self._player_y = int(self._screen_height * np.random.normal(0.5, 0.1))


        obs, _ = self._get_observation()
        info = {"score": self._score}
        return obs, info

    def step(self, action):
        observation, reward, done, truncated, info  = super().step(action)
        (prev_dist, h_dist, v_dist, vel_y,
        lower_pipe_y, upper_pipe_y, player_y) = self._get_observation_features_raw()


        if 0.05 <= v_dist <= 0.15:
            reward = 0
        elif 0.15 <= v_dist:
            reward = -0.05
        elif 0.3 <= v_dist:
            reward = -0.1

        if action == 1 and vel_y < .1:
            reward =- 0.1

        # elif player_y <= 0.1 or player_y >= 0.6:
        #     reward = 0

        dists.append((v_dist, player_y, vel_y, h_dist))
        return observation, reward, done, truncated, info


dists  = []

# %% [markdown]
# # Base simulation

# %%
env = wrap_env(FlappyBirdDiscreteEnv(render_mode="rgb_array"))

base_simulation(env)
# Out:
# Moviepy - Building video /content/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-0.mp4
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# @markdown <h1>Setting the hyperparameters for Q-learning Fally Bird</h1>
alpha = 0.5 # @param {type:"slider", min: 0.0, max:1.0, step: 0.01}
discount_factor = 0.99  # @param {type:"slider", min: 0.0, max:1.0, step: 0.01}
train_episodes = 20000  # @param {type:"integer"}
max_steps = 1500  # @param {type:"integer"}
min_epsilon = 0.10  # @param {type:"number"}
max_epsilon = 1  # @param {type:"integer"}
epsilon_decay = 0.473   # @param {type:"slider", min: 0.0, max:1.0, step: 0.001}
eval_episodes=1  # @param {type:"integer"}


dists  = []
env = FlappyBirdDiscreteEnv(render_mode="rgb_array")

Q, training_rewards, epsilons = q_learning(
    env, train_episodes, epsilon_decay, max_steps,
    eval_episodes, min_epsilon, debug=False
)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Episode 3437: Accumulated reward:       0.79
# Episode 3438: Accumulated reward:       0.27
# Episode 3439: Accumulated reward:      -0.31
# Episode 3440: Accumulated reward:      -0.12
# Episode 3441: Accumulated reward:      -0.09
# Episode 3442: Accumulated reward:       0.28
# Episode 3443: Accumulated reward:      -0.26
# Episode 3444: Accumulated reward:      -0.07
# Episode 3445: Accumulated reward:      -0.01
# Episode 3446: Accumulated reward:      -0.32
# Episode 3447: Accumulated reward:      -0.47
# Episode 3448: Accumulated reward:      -0.60
# Episode 3449: Accumulated reward:      -0.35
# Episode 3450: Accumulated reward:      -0.92
# Episode 3451: Accumulated reward:      -0.35
# Episode 3452: Accumulated reward:      -0.34
# Episode 3453: Accumulated reward:       0.70
# Episode 3454: Accumulated reward:       0.83
# Episode 3455: Accumulated reward:       0.92
# Episode 3456: Accumulated reward:       1.58
# Episode 3457: Accumulated reward:       1.63
# Episode 3458: Accumulated reward:       2.11
# Episode 3459: Accumulated reward:       2.28
# Episode 3460: Accumulated reward:       2.37
# Episode 3461: Accumulated reward:       2.04
# Episode 3462: Accumulated reward:       1.82
# Episode 3463: Accumulated reward:       1.26
# Episode 3464: Accumulated reward:       0.68
# Episode 3465: Accumulated reward:       0.72
# Episode 3466: Accumulated reward:       0.53
# Episode 3467: Accumulated reward:       0.84
# Episode 3468: Accumulated reward:       1.01
# Episode 3469: Accumulated reward:       1.16
# Episode 3470: Accumulated reward:       1.59
# Episode 3471: Accumulated reward:       2.00
# Episode 3472: Accumulated reward:       1.92
# Episode 3473: Accumulated reward:       1.94
# Episode 3474: Accumulated reward:       2.52
# Episode 3475: Accumulated reward:       2.53
# Episode 3476: Accumulated reward:       2.13
# Episode 3477: Accumulated reward:       1.92
# Episode 3478: Accumulated reward:       1.43
# Episode 3479: Accumulated reward:       1.27
# Episode 3480: Accumulated reward:       1.02
# Episode 3481: Accumulated reward:       0.76
# Episode 3482: Accumulated reward:       0.50
# Episode 3483: Accumulated reward:       0.64
# Episode 3484: Accumulated reward:       0.49
# Episode 3485: Accumulated reward:       0.78
# Episode 3486: Accumulated reward:       0.67
# Episode 3487: Accumulated reward:       0.94
# Episode 3488: Accumulated reward:       1.33
# Episode 3489: Accumulated reward:       1.48
# Episode 3490: Accumulated reward:       1.70
# Episode 3491: Accumulated reward:       1.39
# Episode 3492: Accumulated reward:       1.49
# Episode 3493: Accumulated reward:       0.98
# Episode 3494: Accumulated reward:       1.13
# Episode 3495: Accumulated reward:       1.00
# Episode 3496: Accumulated reward:       1.02
# Episode 3497: Accumulated reward:       0.46
# Episode 3498: Accumulated reward:      -0.02
# Episode 3499: Accumulated reward:      -0.17
# Episode 3500: Accumulated reward:      -0.48
# Episode 3501: Accumulated reward:      -0.04
# Episode 3502: Accumulated reward:      -0.22
# Episode 3503: Accumulated reward:       0.17
# Episode 3504: Accumulated reward:       0.27
# Episode 3505: Accumulated reward:       0.41
# Episode 3506: Accumulated reward:       0.89
# Episode 3507: Accumulated reward:       1.48
# Episode 3508: Accumulated reward:       2.12
# Episode 3509: Accumulated reward:       2.24
# Episode 3510: Accumulated reward:       2.72
# Episode 3511: Accumulated reward:       2.87
# Episode 3512: Accumulated reward:       3.63
# Episode 3513: Accumulated reward:       3.69
# Episode 3514: Accumulated reward:       3.61
# Episode 3515: Accumulated reward:       3.73
# Episode 3516: Accumulated reward:       3.65
# Episode 3517: Accumulated reward:       3.49
# Episode 3518: Accumulated reward:       3.23
# Episode 3519: Accumulated reward:       2.65
# Episode 3520: Accumulated reward:       2.41
# Episode 3521: Accumulated reward:       2.06
# Episode 3522: Accumulated reward:       1.87
# Episode 3523: Accumulated reward:       1.71
# Episode 3524: Accumulated reward:       1.40
# Episode 3525: Accumulated reward:       0.84
# Episode 3526: Accumulated reward:       0.66
# Episode 3527: Accumulated reward:       0.51
# Episode 3528: Accumulated reward:       0.28
# Episode 3529: Accumulated reward:       0.29
# Episode 3530: Accumulated reward:       0.36
# Episode 3531: Accumulated reward:       0.48
# Episode 3532: Accumulated reward:       0.42
# Episode 3533: Accumulated reward:       0.03
# Episode 3534: Accumulated reward:      -0.25
# Episode 3535: Accumulated reward:      -0.05
# Episode 3536: Accumulated reward:      -0.38
# Episode 3537: Accumulated reward:      -0.40
# Episode 3538: Accumulated reward:      -0.05
# Episode 3539: Accumulated reward:       0.34
# Episode 3540: Accumulated reward:       0.34
# Episode 3541: Accumulated reward:       0.20
# Episode 3542: Accumulated reward:       0.19
# Episode 3543: Accumulated reward:       0.61
# Episode 3544: Accumulated reward:       0.83
# Episode 3545: Accumulated reward:       0.63
# Episode 3546: Accumulated reward:       1.22
# Episode 3547: Accumulated reward:       1.22
# Episode 3548: Accumulated reward:       0.84
# Episode 3549: Accumulated reward:       0.61
# Episode 3550: Accumulated reward:       0.56
# Episode 3551: Accumulated reward:       0.81
# Episode 3552: Accumulated reward:       1.21
# Episode 3553: Accumulated reward:       1.38
# Episode 3554: Accumulated reward:       1.51
# Episode 3555: Accumulated reward:       1.98
# Episode 3556: Accumulated reward:       1.67
# Episode 3557: Accumulated reward:       1.46
# Episode 3558: Accumulated reward:       1.75
# Episode 3559: Accumulated reward:       1.58
# Episode 3560: Accumulated reward:       1.44
# Episode 3561: Accumulated reward:       1.17
# Episode 3562: Accumulated reward:       0.43
# Episode 3563: Accumulated reward:       0.40
# Episode 3564: Accumulated reward:       0.40
# Episode 3565: Accumulated reward:       0.36
# Episode 3566: Accumulated reward:       0.88
# Episode 3567: Accumulated reward:       1.33
# Episode 3568: Accumulated reward:       1.30
# Episode 3569: Accumulated reward:       1.68
# Episode 3570: Accumulated reward:       1.63
# Episode 3571: Accumulated reward:       1.52
# Episode 3572: Accumulated reward:       1.70
# Episode 3573: Accumulated reward:       1.41
# Episode 3574: Accumulated reward:       1.63
# Episode 3575: Accumulated reward:       1.60
# Episode 3576: Accumulated reward:       1.68
# Episode 3577: Accumulated reward:       1.77
# Episode 3578: Accumulated reward:       1.95
# Episode 3579: Accumulated reward:       2.17
# Episode 3580: Accumulated reward:       2.57
# Episode 3581: Accumulated reward:       2.48
# Episode 3582: Accumulated reward:       2.40
# Episode 3583: Accumulated reward:       2.38
# Episode 3584: Accumulated reward:       1.96
# Episode 3585: Accumulated reward:       1.83
# Episode 3586: Accumulated reward:       1.55
# Episode 3587: Accumulated reward:       1.31
# Episode 3588: Accumulated reward:       0.97
# Episode 3589: Accumulated reward:       0.46
# Episode 3590: Accumulated reward:       0.11
# Episode 3591: Accumulated reward:      -0.01
# Episode 3592: Accumulated reward:      -0.23
# Episode 3593: Accumulated reward:      -0.04
# Episode 3594: Accumulated reward:      -0.18
# Episode 3595: Accumulated reward:       0.36
# Episode 3596: Accumulated reward:       0.23
# Episode 3597: Accumulated reward:       0.31
# Episode 3598: Accumulated reward:       0.10
# Episode 3599: Accumulated reward:       0.23
# Episode 3600: Accumulated reward:       0.59
# Episode 3601: Accumulated reward:       1.05
# Episode 3602: Accumulated reward:       1.67
# Episode 3603: Accumulated reward:       1.83
# Episode 3604: Accumulated reward:       1.93
# Episode 3605: Accumulated reward:       1.36
# Episode 3606: Accumulated reward:       1.49
# Episode 3607: Accumulated reward:       1.48
# Episode 3608: Accumulated reward:       1.74
# Episode 3609: Accumulated reward:       1.81
# Episode 3610: Accumulated reward:       1.34
# Episode 3611: Accumulated reward:       1.16
# Episode 3612: Accumulated reward:       1.01
# Episode 3613: Accumulated reward:       1.40
# Episode 3614: Accumulated reward:       1.76
# Episode 3615: Accumulated reward:       1.71
# Episode 3616: Accumulated reward:       1.71
# Episode 3617: Accumulated reward:       1.55
# Episode 3618: Accumulated reward:       1.87
# Episode 3619: Accumulated reward:       2.18
# Episode 3620: Accumulated reward:       2.50
# Episode 3621: Accumulated reward:       2.68
# Episode 3622: Accumulated reward:       2.85
# Episode 3623: Accumulated reward:       2.32
# Episode 3624: Accumulated reward:       2.46
# Episode 3625: Accumulated reward:       2.55
# Episode 3626: Accumulated reward:       1.95
# Episode 3627: Accumulated reward:       1.86
# Episode 3628: Accumulated reward:       1.45
# Episode 3629: Accumulated reward:       0.93
# Episode 3630: Accumulated reward:       0.51
# Episode 3631: Accumulated reward:       0.47
# Episode 3632: Accumulated reward:       0.11
# Episode 3633: Accumulated reward:      -0.29
# Episode 3634: Accumulated reward:      -0.90
# Episode 3635: Accumulated reward:      -1.22
# Episode 3636: Accumulated reward:      -0.70
# Episode 3637: Accumulated reward:      -0.51
# Episode 3638: Accumulated reward:      -0.52
# Episode 3639: Accumulated reward:       0.23
# Episode 3640: Accumulated reward:       0.75
# Episode 3641: Accumulated reward:       1.44
# Episode 3642: Accumulated reward:       1.45
# Episode 3643: Accumulated reward:       1.92
# Episode 3644: Accumulated reward:       2.46
# Episode 3645: Accumulated reward:       3.48
# Episode 3646: Accumulated reward:       3.42
# Episode 3647: Accumulated reward:       3.16
# Episode 3648: Accumulated reward:       3.03
# Episode 3649: Accumulated reward:       2.58
# Episode 3650: Accumulated reward:       2.77
# Episode 3651: Accumulated reward:       1.88
# Episode 3652: Accumulated reward:       2.03
# Episode 3653: Accumulated reward:       1.95
# Episode 3654: Accumulated reward:       1.76
# Episode 3655: Accumulated reward:       1.34
# Episode 3656: Accumulated reward:       1.36
# Episode 3657: Accumulated reward:       1.42
# Episode 3658: Accumulated reward:       1.32
# Episode 3659: Accumulated reward:       0.90
# Episode 3660: Accumulated reward:       0.25
# Episode 3661: Accumulated reward:       0.06
# Episode 3662: Accumulated reward:       0.09
# Episode 3663: Accumulated reward:       0.27
# Episode 3664: Accumulated reward:       0.59
# Episode 3665: Accumulated reward:       0.38
# Episode 3666: Accumulated reward:       0.56
# Episode 3667: Accumulated reward:       0.75
# Episode 3668: Accumulated reward:       1.00
# Episode 3669: Accumulated reward:       1.15
# Episode 3670: Accumulated reward:       1.21
# Episode 3671: Accumulated reward:       1.73
# Episode 3672: Accumulated reward:       1.60
# Episode 3673: Accumulated reward:       1.31
# Episode 3674: Accumulated reward:       1.15
# Episode 3675: Accumulated reward:       1.36
# Episode 3676: Accumulated reward:       1.00
# Episode 3677: Accumulated reward:       1.09
# Episode 3678: Accumulated reward:       1.13
# Episode 3679: Accumulated reward:       1.10
# Episode 3680: Accumulated reward:       1.39
# Episode 3681: Accumulated reward:       1.44
# Episode 3682: Accumulated reward:       1.38
# Episode 3683: Accumulated reward:       1.48
# Episode 3684: Accumulated reward:       1.27
# Episode 3685: Accumulated reward:       1.08
# Episode 3686: Accumulated reward:       1.36
# Episode 3687: Accumulated reward:       1.34
# Episode 3688: Accumulated reward:       1.65
# Episode 3689: Accumulated reward:       2.02
# Episode 3690: Accumulated reward:       2.05
# Episode 3691: Accumulated reward:       1.92
# Episode 3692: Accumulated reward:       2.11
# Episode 3693: Accumulated reward:       2.27
# Episode 3694: Accumulated reward:       2.30
# Episode 3695: Accumulated reward:       2.42
# Episode 3696: Accumulated reward:       2.29
# Episode 3697: Accumulated reward:       1.96
# Episode 3698: Accumulated reward:       2.00
# Episode 3699: Accumulated reward:       1.72
# Episode 3700: Accumulated reward:       1.67
# Episode 3701: Accumulated reward:       1.32
# Episode 3702: Accumulated reward:       0.91
# Episode 3703: Accumulated reward:       0.75
# Episode 3704: Accumulated reward:       0.73
# Episode 3705: Accumulated reward:       0.57
# Episode 3706: Accumulated reward:       0.29
# Episode 3707: Accumulated reward:       0.51
# Episode 3708: Accumulated reward:       0.35
# Episode 3709: Accumulated reward:       0.64
# Episode 3710: Accumulated reward:       0.78
# Episode 3711: Accumulated reward:       1.35
# Episode 3712: Accumulated reward:       1.91
# Episode 3713: Accumulated reward:       1.87
# Episode 3714: Accumulated reward:       2.06
# Episode 3715: Accumulated reward:       2.02
# Episode 3716: Accumulated reward:       2.37
# Episode 3717: Accumulated reward:       2.44
# Episode 3718: Accumulated reward:       2.03
# Episode 3719: Accumulated reward:       1.75
# Episode 3720: Accumulated reward:       1.31
# Episode 3721: Accumulated reward:       0.72
# Episode 3722: Accumulated reward:       0.46
# Episode 3723: Accumulated reward:       0.51
# Episode 3724: Accumulated reward:      -0.03
# Episode 3725: Accumulated reward:       0.08
# Episode 3726: Accumulated reward:      -0.04
# Episode 3727: Accumulated reward:      -0.29
# Episode 3728: Accumulated reward:      -0.31
# Episode 3729: Accumulated reward:      -0.44
# Episode 3730: Accumulated reward:      -0.12
# Episode 3731: Accumulated reward:       0.26
# Episode 3732: Accumulated reward:       0.52
# Episode 3733: Accumulated reward:       0.52
# Episode 3734: Accumulated reward:       1.04
# Episode 3735: Accumulated reward:       0.96
# Episode 3736: Accumulated reward:       0.71
# Episode 3737: Accumulated reward:       0.57
# Episode 3738: Accumulated reward:       1.18
# Episode 3739: Accumulated reward:       1.16
# Episode 3740: Accumulated reward:       1.16
# Episode 3741: Accumulated reward:       1.24
# Episode 3742: Accumulated reward:       1.24
# Episode 3743: Accumulated reward:       1.20
# Episode 3744: Accumulated reward:       0.99
# Episode 3745: Accumulated reward:       1.09
# Episode 3746: Accumulated reward:       1.54
# Episode 3747: Accumulated reward:       2.06
# Episode 3748: Accumulated reward:       2.02
# Episode 3749: Accumulated reward:       2.56
# Episode 3750: Accumulated reward:       2.41
# Episode 3751: Accumulated reward:       2.05
# Episode 3752: Accumulated reward:       1.68
# Episode 3753: Accumulated reward:       1.41
# Episode 3754: Accumulated reward:       1.55
# Episode 3755: Accumulated reward:       1.54
# Episode 3756: Accumulated reward:       1.39
# Episode 3757: Accumulated reward:       1.06
# Episode 3758: Accumulated reward:       0.52
# Episode 3759: Accumulated reward:       0.56
# Episode 3760: Accumulated reward:       0.49
# Episode 3761: Accumulated reward:       0.78
# Episode 3762: Accumulated reward:       1.13
# Episode 3763: Accumulated reward:       1.55
# Episode 3764: Accumulated reward:       1.72
# Episode 3765: Accumulated reward:       1.73
# Episode 3766: Accumulated reward:       1.94
# Episode 3767: Accumulated reward:       2.26
# Episode 3768: Accumulated reward:       2.78
# Episode 3769: Accumulated reward:       2.87
# Episode 3770: Accumulated reward:       3.02
# Episode 3771: Accumulated reward:       3.43
# Episode 3772: Accumulated reward:       3.38
# Episode 3773: Accumulated reward:       3.66
# Episode 3774: Accumulated reward:       3.37
# Episode 3775: Accumulated reward:       3.07
# Episode 3776: Accumulated reward:       2.67
# Episode 3777: Accumulated reward:       2.34
# Episode 3778: Accumulated reward:       2.37
# Episode 3779: Accumulated reward:       1.77
# Episode 3780: Accumulated reward:       1.86
# Episode 3781: Accumulated reward:       1.45
# Episode 3782: Accumulated reward:       1.66
# Episode 3783: Accumulated reward:       1.44
# Episode 3784: Accumulated reward:       1.71
# Episode 3785: Accumulated reward:       1.95
# Episode 3786: Accumulated reward:       2.29
# Episode 3787: Accumulated reward:       2.96
# Episode 3788: Accumulated reward:       2.80
# Episode 3789: Accumulated reward:       3.02
# Episode 3790: Accumulated reward:       2.76
# Episode 3791: Accumulated reward:       2.51
# Episode 3792: Accumulated reward:       2.14
# Episode 3793: Accumulated reward:       2.11
# Episode 3794: Accumulated reward:       1.84
# Episode 3795: Accumulated reward:       1.89
# Episode 3796: Accumulated reward:       1.74
# Episode 3797: Accumulated reward:       1.33
# Episode 3798: Accumulated reward:       1.30
# Episode 3799: Accumulated reward:       1.56
# Episode 3800: Accumulated reward:       1.95
# Episode 3801: Accumulated reward:       2.26
# Episode 3802: Accumulated reward:       2.45
# Episode 3803: Accumulated reward:       2.03
# Episode 3804: Accumulated reward:       1.96
# Episode 3805: Accumulated reward:       1.54
# Episode 3806: Accumulated reward:       1.37
# Episode 3807: Accumulated reward:       1.11
# Episode 3808: Accumulated reward:       0.82
# Episode 3809: Accumulated reward:       0.15
# Episode 3810: Accumulated reward:      -0.45
# Episode 3811: Accumulated reward:      -0.89
# Episode 3812: Accumulated reward:      -1.33
# Episode 3813: Accumulated reward:      -0.94
# Episode 3814: Accumulated reward:      -0.65
# Episode 3815: Accumulated reward:      -0.06
# Episode 3816: Accumulated reward:       0.00
# Episode 3817: Accumulated reward:       0.03
# Episode 3818: Accumulated reward:      -0.04
# Episode 3819: Accumulated reward:       0.48
# Episode 3820: Accumulated reward:       0.93
# Episode 3821: Accumulated reward:       1.43
# Episode 3822: Accumulated reward:       1.93
# Episode 3823: Accumulated reward:       1.68
# Episode 3824: Accumulated reward:       1.25
# Episode 3825: Accumulated reward:       1.43
# Episode 3826: Accumulated reward:       1.52
# Episode 3827: Accumulated reward:       1.92
# Episode 3828: Accumulated reward:       2.38
# Episode 3829: Accumulated reward:       2.38
# Episode 3830: Accumulated reward:       2.13
# Episode 3831: Accumulated reward:       1.71
# Episode 3832: Accumulated reward:       1.38
# Episode 3833: Accumulated reward:       1.50
# Episode 3834: Accumulated reward:       1.56
# Episode 3835: Accumulated reward:       1.01
# Episode 3836: Accumulated reward:       0.88
# Episode 3837: Accumulated reward:       0.27
# Episode 3838: Accumulated reward:      -0.20
# Episode 3839: Accumulated reward:      -0.29
# Episode 3840: Accumulated reward:      -0.05
# Episode 3841: Accumulated reward:      -0.16
# Episode 3842: Accumulated reward:       0.18
# Episode 3843: Accumulated reward:       0.34
# Episode 3844: Accumulated reward:       0.81
# Episode 3845: Accumulated reward:       0.82
# Episode 3846: Accumulated reward:       0.72
# Episode 3847: Accumulated reward:       0.74
# Episode 3848: Accumulated reward:       1.27
# Episode 3849: Accumulated reward:       1.51
# Episode 3850: Accumulated reward:       1.53
# Episode 3851: Accumulated reward:       1.73
# Episode 3852: Accumulated reward:       1.35
# Episode 3853: Accumulated reward:       0.94
# Episode 3854: Accumulated reward:       0.53
# Episode 3855: Accumulated reward:       0.34
# Episode 3856: Accumulated reward:       0.35
# Episode 3857: Accumulated reward:       0.69
# Episode 3858: Accumulated reward:       0.22
# Episode 3859: Accumulated reward:      -0.35
# Episode 3860: Accumulated reward:      -0.71
# Episode 3861: Accumulated reward:      -0.78
# Episode 3862: Accumulated reward:      -0.67
# Episode 3863: Accumulated reward:      -0.74
# Episode 3864: Accumulated reward:      -0.40
# Episode 3865: Accumulated reward:       0.43
# Episode 3866: Accumulated reward:       0.50
# Episode 3867: Accumulated reward:       0.70
# Episode 3868: Accumulated reward:       0.67
# Episode 3869: Accumulated reward:       0.75
# Episode 3870: Accumulated reward:       0.73
# Episode 3871: Accumulated reward:       1.21
# Episode 3872: Accumulated reward:       1.15
# Episode 3873: Accumulated reward:       1.42
# Episode 3874: Accumulated reward:       1.46
# Episode 3875: Accumulated reward:       1.00
# Episode 3876: Accumulated reward:       0.75
# Episode 3877: Accumulated reward:       0.24
# Episode 3878: Accumulated reward:       0.19
# Episode 3879: Accumulated reward:       0.26
# Episode 3880: Accumulated reward:       0.42
# Episode 3881: Accumulated reward:       0.37
# Episode 3882: Accumulated reward:       0.42
# Episode 3883: Accumulated reward:       0.37
# Episode 3884: Accumulated reward:       0.01
# Episode 3885: Accumulated reward:       0.17
# Episode 3886: Accumulated reward:       0.45
# Episode 3887: Accumulated reward:       0.57
# Episode 3888: Accumulated reward:       0.53
# Episode 3889: Accumulated reward:       0.41
# Episode 3890: Accumulated reward:       0.68
# Episode 3891: Accumulated reward:       0.70
# Episode 3892: Accumulated reward:       0.88
# Episode 3893: Accumulated reward:       1.03
# Episode 3894: Accumulated reward:       0.92
# Episode 3895: Accumulated reward:       0.95
# Episode 3896: Accumulated reward:       1.24
# Episode 3897: Accumulated reward:       1.53
# Episode 3898: Accumulated reward:       1.83
# Episode 3899: Accumulated reward:       2.38
# Episode 3900: Accumulated reward:       1.90
# Episode 3901: Accumulated reward:       1.91
# Episode 3902: Accumulated reward:       1.44
# Episode 3903: Accumulated reward:       1.24
# Episode 3904: Accumulated reward:       1.47
# Episode 3905: Accumulated reward:       1.35
# Episode 3906: Accumulated reward:       1.17
# Episode 3907: Accumulated reward:       1.20
# Episode 3908: Accumulated reward:       1.40
# Episode 3909: Accumulated reward:       0.97
# Episode 3910: Accumulated reward:       1.52
# Episode 3911: Accumulated reward:       1.47
# Episode 3912: Accumulated reward:       1.86
# Episode 3913: Accumulated reward:       2.03
# Episode 3914: Accumulated reward:       2.09
# Episode 3915: Accumulated reward:       2.00
# Episode 3916: Accumulated reward:       2.02
# Episode 3917: Accumulated reward:       1.96
# Episode 3918: Accumulated reward:       1.84
# Episode 3919: Accumulated reward:       2.19
# Episode 3920: Accumulated reward:       1.90
# Episode 3921: Accumulated reward:       1.29
# Episode 3922: Accumulated reward:       1.49
# Episode 3923: Accumulated reward:       1.64
# Episode 3924: Accumulated reward:       1.53
# Episode 3925: Accumulated reward:       1.78
# Episode 3926: Accumulated reward:       1.76
# Episode 3927: Accumulated reward:       1.73
# Episode 3928: Accumulated reward:       1.94
# Episode 3929: Accumulated reward:       1.65
# Episode 3930: Accumulated reward:       1.81
# Episode 3931: Accumulated reward:       2.28
# Episode 3932: Accumulated reward:       2.13
# Episode 3933: Accumulated reward:       1.67
# Episode 3934: Accumulated reward:       1.78
# Episode 3935: Accumulated reward:       1.44
# Episode 3936: Accumulated reward:       1.46
# Episode 3937: Accumulated reward:       1.30
# Episode 3938: Accumulated reward:       0.83
# Episode 3939: Accumulated reward:       1.22
# Episode 3940: Accumulated reward:       1.37
# Episode 3941: Accumulated reward:       1.52
# Episode 3942: Accumulated reward:       1.62
# Episode 3943: Accumulated reward:       2.15
# Episode 3944: Accumulated reward:       2.15
# Episode 3945: Accumulated reward:       2.44
# Episode 3946: Accumulated reward:       2.12
# Episode 3947: Accumulated reward:       2.48
# Episode 3948: Accumulated reward:       2.75
# Episode 3949: Accumulated reward:       2.31
# Episode 3950: Accumulated reward:       2.28
# Episode 3951: Accumulated reward:       2.17
# Episode 3952: Accumulated reward:       1.87
# Episode 3953: Accumulated reward:       1.63
# Episode 3954: Accumulated reward:       1.74
# Episode 3955: Accumulated reward:       1.74
# Episode 3956: Accumulated reward:       2.21
# Episode 3957: Accumulated reward:       2.22
# Episode 3958: Accumulated reward:       2.56
# Episode 3959: Accumulated reward:       3.21
# Episode 3960: Accumulated reward:       3.12
# Episode 3961: Accumulated reward:       2.83
# Episode 3962: Accumulated reward:       3.01
# Episode 3963: Accumulated reward:       3.15
# Episode 3964: Accumulated reward:       2.66
# Episode 3965: Accumulated reward:       2.15
# Episode 3966: Accumulated reward:       1.62
# Episode 3967: Accumulated reward:       1.00
# Episode 3968: Accumulated reward:       0.42
# Episode 3969: Accumulated reward:      -0.30
# Episode 3970: Accumulated reward:      -0.86
# Episode 3971: Accumulated reward:      -0.38
# Episode 3972: Accumulated reward:      -0.36
# Episode 3973: Accumulated reward:      -0.38
# Episode 3974: Accumulated reward:      -0.08
# Episode 3975: Accumulated reward:       0.45
# Episode 3976: Accumulated reward:       0.96
# Episode 3977: Accumulated reward:       1.56
# Episode 3978: Accumulated reward:       1.67
# Episode 3979: Accumulated reward:       1.76
# Episode 3980: Accumulated reward:       1.81
# Episode 3981: Accumulated reward:       1.58
# Episode 3982: Accumulated reward:       1.36
# Episode 3983: Accumulated reward:       1.32
# Episode 3984: Accumulated reward:       1.28
# Episode 3985: Accumulated reward:       0.68
# Episode 3986: Accumulated reward:       0.40
# Episode 3987: Accumulated reward:       0.06
# Episode 3988: Accumulated reward:       0.18
# Episode 3989: Accumulated reward:       0.43
# Episode 3990: Accumulated reward:       0.57
# Episode 3991: Accumulated reward:       0.58
# Episode 3992: Accumulated reward:       0.80
# Episode 3993: Accumulated reward:       0.61
# Episode 3994: Accumulated reward:       1.02
# Episode 3995: Accumulated reward:       1.46
# Episode 3996: Accumulated reward:       1.27
# Episode 3997: Accumulated reward:       1.02
# Episode 3998: Accumulated reward:       0.68
# Episode 3999: Accumulated reward:       0.51
# Episode 4000: Accumulated reward:       0.91
# Episode 4001: Accumulated reward:       0.76
# Episode 4002: Accumulated reward:       0.49
# Episode 4003: Accumulated reward:       0.40
# Episode 4004: Accumulated reward:      -0.29
# Episode 4005: Accumulated reward:      -0.67
# Episode 4006: Accumulated reward:      -0.67
# Episode 4007: Accumulated reward:      -0.45
# Episode 4008: Accumulated reward:      -0.35
# Episode 4009: Accumulated reward:      -0.04
# Episode 4010: Accumulated reward:      -0.35
# Episode 4011: Accumulated reward:      -0.30
# Episode 4012: Accumulated reward:      -0.17
# Episode 4013: Accumulated reward:       0.06
# Episode 4014: Accumulated reward:       0.19
# Episode 4015: Accumulated reward:       0.56
# Episode 4016: Accumulated reward:       0.73
# Episode 4017: Accumulated reward:       0.48
# Episode 4018: Accumulated reward:       0.81
# Episode 4019: Accumulated reward:       0.66
# Episode 4020: Accumulated reward:       0.98
# Episode 4021: Accumulated reward:       1.04
# Episode 4022: Accumulated reward:       0.96
# Episode 4023: Accumulated reward:       0.73
# Episode 4024: Accumulated reward:       0.92
# Episode 4025: Accumulated reward:       1.12
# Episode 4026: Accumulated reward:       1.50
# Episode 4027: Accumulated reward:       2.20
# Episode 4028: Accumulated reward:       2.31
# Episode 4029: Accumulated reward:       2.71
# Episode 4030: Accumulated reward:       2.63
# Episode 4031: Accumulated reward:       2.83
# Episode 4032: Accumulated reward:       2.98
# Episode 4033: Accumulated reward:       3.45
# Episode 4034: Accumulated reward:       3.52
# Episode 4035: Accumulated reward:       3.09
# Episode 4036: Accumulated reward:       3.04
# Episode 4037: Accumulated reward:       2.79
# Episode 4038: Accumulated reward:       2.68
# Episode 4039: Accumulated reward:       2.14
# Episode 4040: Accumulated reward:       2.05
# Episode 4041: Accumulated reward:       1.76
# Episode 4042: Accumulated reward:       1.30
# Episode 4043: Accumulated reward:       1.05
# Episode 4044: Accumulated reward:       0.81
# Episode 4045: Accumulated reward:       0.80
# Episode 4046: Accumulated reward:       0.24
# Episode 4047: Accumulated reward:       0.24
# Episode 4048: Accumulated reward:      -0.06
# Episode 4049: Accumulated reward:       0.03
# Episode 4050: Accumulated reward:       0.26
# Episode 4051: Accumulated reward:       0.53
# Episode 4052: Accumulated reward:       1.13
# Episode 4053: Accumulated reward:       1.21
# Episode 4054: Accumulated reward:       1.43
# Episode 4055: Accumulated reward:       2.31
# Episode 4056: Accumulated reward:       2.83
# Episode 4057: Accumulated reward:       2.98
# Episode 4058: Accumulated reward:       3.52
# Episode 4059: Accumulated reward:       3.72
# Episode 4060: Accumulated reward:       3.64
# Episode 4061: Accumulated reward:       3.69
# Episode 4062: Accumulated reward:       3.66
# Episode 4063: Accumulated reward:       3.36
# Episode 4064: Accumulated reward:       3.59
# Episode 4065: Accumulated reward:       2.56
# Episode 4066: Accumulated reward:       2.35
# Episode 4067: Accumulated reward:       1.82
# Episode 4068: Accumulated reward:       1.43
# Episode 4069: Accumulated reward:       1.06
# Episode 4070: Accumulated reward:       0.58
# Episode 4071: Accumulated reward:       0.21
# Episode 4072: Accumulated reward:      -0.36
# Episode 4073: Accumulated reward:      -0.01
# Episode 4074: Accumulated reward:      -0.61
# Episode 4075: Accumulated reward:      -0.41
# Episode 4076: Accumulated reward:      -0.60
# Episode 4077: Accumulated reward:      -0.32
# Episode 4078: Accumulated reward:      -0.25
# Episode 4079: Accumulated reward:      -0.13
# Episode 4080: Accumulated reward:       0.67
# Episode 4081: Accumulated reward:       0.71
# Episode 4082: Accumulated reward:       1.26
# Episode 4083: Accumulated reward:       1.26
# Episode 4084: Accumulated reward:       1.79
# Episode 4085: Accumulated reward:       1.92
# Episode 4086: Accumulated reward:       2.37
# Episode 4087: Accumulated reward:       2.49
# Episode 4088: Accumulated reward:       2.27
# Episode 4089: Accumulated reward:       2.07
# Episode 4090: Accumulated reward:       1.49
# Episode 4091: Accumulated reward:       1.63
# Episode 4092: Accumulated reward:       1.18
# Episode 4093: Accumulated reward:       0.67
# Episode 4094: Accumulated reward:       0.83
# Episode 4095: Accumulated reward:       0.74
# Episode 4096: Accumulated reward:       0.59
# Episode 4097: Accumulated reward:       0.44
# Episode 4098: Accumulated reward:       0.86
# Episode 4099: Accumulated reward:       1.15
# Episode 4100: Accumulated reward:       1.51
# Episode 4101: Accumulated reward:       1.47
# Episode 4102: Accumulated reward:       1.93
# Episode 4103: Accumulated reward:       2.23
# Episode 4104: Accumulated reward:       2.03
# Episode 4105: Accumulated reward:       2.09
# Episode 4106: Accumulated reward:       2.27
# Episode 4107: Accumulated reward:       2.56
# Episode 4108: Accumulated reward:       2.44
# Episode 4109: Accumulated reward:       2.17
# Episode 4110: Accumulated reward:       2.02
# Episode 4111: Accumulated reward:       1.87
# Episode 4112: Accumulated reward:       1.46
# Episode 4113: Accumulated reward:       1.30
# Episode 4114: Accumulated reward:       1.37
# Episode 4115: Accumulated reward:       1.38
# Episode 4116: Accumulated reward:       1.04
# Episode 4117: Accumulated reward:       1.02
# Episode 4118: Accumulated reward:       1.02
# Episode 4119: Accumulated reward:       1.45
# Episode 4120: Accumulated reward:       1.60
# Episode 4121: Accumulated reward:       1.98
# Episode 4122: Accumulated reward:       2.50
# Episode 4123: Accumulated reward:       2.66
# Episode 4124: Accumulated reward:       2.45
# Episode 4125: Accumulated reward:       2.53
# Episode 4126: Accumulated reward:       2.84
# Episode 4127: Accumulated reward:       2.77
# Episode 4128: Accumulated reward:       2.94
# Episode 4129: Accumulated reward:       2.70
# Episode 4130: Accumulated reward:       2.45
# Episode 4131: Accumulated reward:       2.25
# Episode 4132: Accumulated reward:       1.72
# Episode 4133: Accumulated reward:       2.13
# Episode 4134: Accumulated reward:       1.72
# Episode 4135: Accumulated reward:       1.27
# Episode 4136: Accumulated reward:       0.65
# Episode 4137: Accumulated reward:       0.10
# Episode 4138: Accumulated reward:      -0.55
# Episode 4139: Accumulated reward:      -0.55
# Episode 4140: Accumulated reward:      -0.30
# Episode 4141: Accumulated reward:      -0.45
# Episode 4142: Accumulated reward:      -0.07
# Episode 4143: Accumulated reward:      -0.40
# Episode 4144: Accumulated reward:       0.28
# Episode 4145: Accumulated reward:       0.52
# Episode 4146: Accumulated reward:       0.57
# Episode 4147: Accumulated reward:       1.23
# Episode 4148: Accumulated reward:       1.34
# Episode 4149: Accumulated reward:       0.96
# Episode 4150: Accumulated reward:       0.90
# Episode 4151: Accumulated reward:       1.18
# Episode 4152: Accumulated reward:       1.03
# Episode 4153: Accumulated reward:       0.51
# Episode 4154: Accumulated reward:       0.30
# Episode 4155: Accumulated reward:       0.51
# Episode 4156: Accumulated reward:       0.63
# Episode 4157: Accumulated reward:       0.05
# Episode 4158: Accumulated reward:      -0.09
# Episode 4159: Accumulated reward:       0.25
# Episode 4160: Accumulated reward:      -0.36
# Episode 4161: Accumulated reward:      -0.30
# Episode 4162: Accumulated reward:      -0.07
# Episode 4163: Accumulated reward:       0.38
# Episode 4164: Accumulated reward:       0.39
# Episode 4165: Accumulated reward:       0.04
# Episode 4166: Accumulated reward:       0.29
# Episode 4167: Accumulated reward:       0.53
# Episode 4168: Accumulated reward:       1.29
# Episode 4169: Accumulated reward:       1.31
# Episode 4170: Accumulated reward:       1.95
# Episode 4171: Accumulated reward:       1.86
# Episode 4172: Accumulated reward:       1.33
# Episode 4173: Accumulated reward:       0.89
# Episode 4174: Accumulated reward:       0.47
# Episode 4175: Accumulated reward:       0.37
# Episode 4176: Accumulated reward:       0.26
# Episode 4177: Accumulated reward:      -0.10
# Episode 4178: Accumulated reward:      -0.57
# Episode 4179: Accumulated reward:       0.02
# Episode 4180: Accumulated reward:      -0.07
# Episode 4181: Accumulated reward:       0.03
# Episode 4182: Accumulated reward:       0.47
# Episode 4183: Accumulated reward:       1.00
# Episode 4184: Accumulated reward:       1.41
# Episode 4185: Accumulated reward:       1.69
# Episode 4186: Accumulated reward:       1.95
# Episode 4187: Accumulated reward:       2.48
# Episode 4188: Accumulated reward:       2.55
# Episode 4189: Accumulated reward:       2.58
# Episode 4190: Accumulated reward:       2.22
# Episode 4191: Accumulated reward:       1.80
# Episode 4192: Accumulated reward:       1.94
# Episode 4193: Accumulated reward:       2.20
# Episode 4194: Accumulated reward:       2.29
# Episode 4195: Accumulated reward:       2.66
# Episode 4196: Accumulated reward:       2.27
# Episode 4197: Accumulated reward:       2.22
# Episode 4198: Accumulated reward:       2.06
# Episode 4199: Accumulated reward:       1.69
# Episode 4200: Accumulated reward:       1.74
# Episode 4201: Accumulated reward:       1.97
# Episode 4202: Accumulated reward:       1.48
# Episode 4203: Accumulated reward:       0.88
# Episode 4204: Accumulated reward:       1.30
# Episode 4205: Accumulated reward:       1.03
# Episode 4206: Accumulated reward:       1.46
# Episode 4207: Accumulated reward:       1.66
# Episode 4208: Accumulated reward:       2.10
# Episode 4209: Accumulated reward:       2.01
# Episode 4210: Accumulated reward:       2.43
# Episode 4211: Accumulated reward:       2.16
# Episode 4212: Accumulated reward:       2.55
# Episode 4213: Accumulated reward:       2.46
# Episode 4214: Accumulated reward:       1.44
# Episode 4215: Accumulated reward:       1.18
# Episode 4216: Accumulated reward:       1.22
# Episode 4217: Accumulated reward:       0.53
# Episode 4218: Accumulated reward:       0.40
# Episode 4219: Accumulated reward:       0.05
# Episode 4220: Accumulated reward:      -0.55
# Episode 4221: Accumulated reward:      -0.55
# Episode 4222: Accumulated reward:      -0.44
# Episode 4223: Accumulated reward:      -0.02
# Episode 4224: Accumulated reward:       0.61
# Episode 4225: Accumulated reward:       1.08
# Episode 4226: Accumulated reward:       0.89
# Episode 4227: Accumulated reward:       1.54
# Episode 4228: Accumulated reward:       1.81
# Episode 4229: Accumulated reward:       2.29
# Episode 4230: Accumulated reward:       2.37
# Episode 4231: Accumulated reward:       2.22
# Episode 4232: Accumulated reward:       1.78
# Episode 4233: Accumulated reward:       1.98
# Episode 4234: Accumulated reward:       2.08
# Episode 4235: Accumulated reward:       1.95
# Episode 4236: Accumulated reward:       1.88
# Episode 4237: Accumulated reward:       1.51
# Episode 4238: Accumulated reward:       1.39
# Episode 4239: Accumulated reward:       1.19
# Episode 4240: Accumulated reward:       1.15
# Episode 4241: Accumulated reward:       1.40
# Episode 4242: Accumulated reward:       1.44
# Episode 4243: Accumulated reward:       0.82
# Episode 4244: Accumulated reward:       0.14
# Episode 4245: Accumulated reward:      -0.15
# Episode 4246: Accumulated reward:      -0.33
# Episode 4247: Accumulated reward:      -0.29
# Episode 4248: Accumulated reward:      -0.92
# Episode 4249: Accumulated reward:      -0.72
# Episode 4250: Accumulated reward:      -0.70
# Episode 4251: Accumulated reward:      -0.60
# Episode 4252: Accumulated reward:      -0.15
# Episode 4253: Accumulated reward:       0.41
# Episode 4254: Accumulated reward:       0.91
# Episode 4255: Accumulated reward:       0.90
# Episode 4256: Accumulated reward:       1.14
# Episode 4257: Accumulated reward:       1.38
# Episode 4258: Accumulated reward:       1.60
# Episode 4259: Accumulated reward:       1.38
# Episode 4260: Accumulated reward:       1.78
# Episode 4261: Accumulated reward:       1.40
# Episode 4262: Accumulated reward:       0.92
# Episode 4263: Accumulated reward:       0.54
# Episode 4264: Accumulated reward:       0.34
# Episode 4265: Accumulated reward:       0.26
# Episode 4266: Accumulated reward:       0.51
# Episode 4267: Accumulated reward:       0.82
# Episode 4268: Accumulated reward:       1.23
# Episode 4269: Accumulated reward:       1.42
# Episode 4270: Accumulated reward:       1.52
# Episode 4271: Accumulated reward:       1.96
# Episode 4272: Accumulated reward:       2.41
# Episode 4273: Accumulated reward:       2.89
# Episode 4274: Accumulated reward:       3.45
# Episode 4275: Accumulated reward:       4.09
# Episode 4276: Accumulated reward:       3.73
# Episode 4277: Accumulated reward:       3.17
# Episode 4278: Accumulated reward:       2.67
# Episode 4279: Accumulated reward:       2.19
# Episode 4280: Accumulated reward:       1.86
# Episode 4281: Accumulated reward:       1.81
# Episode 4282: Accumulated reward:       1.16
# Episode 4283: Accumulated reward:       0.51
# Episode 4284: Accumulated reward:      -0.25
# Episode 4285: Accumulated reward:      -1.03
# Episode 4286: Accumulated reward:      -0.95
# Episode 4287: Accumulated reward:      -1.00
# Episode 4288: Accumulated reward:      -0.57
# Episode 4289: Accumulated reward:      -0.37
# Episode 4290: Accumulated reward:       0.08
# Episode 4291: Accumulated reward:       0.43
# Episode 4292: Accumulated reward:       0.94
# Episode 4293: Accumulated reward:       1.38
# Episode 4294: Accumulated reward:       1.79
# Episode 4295: Accumulated reward:       2.43
# Episode 4296: Accumulated reward:       2.60
# Episode 4297: Accumulated reward:       3.12
# Episode 4298: Accumulated reward:       2.98
# Episode 4299: Accumulated reward:       2.81
# Episode 4300: Accumulated reward:       2.60
# Episode 4301: Accumulated reward:       2.33
# Episode 4302: Accumulated reward:       2.64
# Episode 4303: Accumulated reward:       2.75
# Episode 4304: Accumulated reward:       2.91
# Episode 4305: Accumulated reward:       2.55
# Episode 4306: Accumulated reward:       2.42
# Episode 4307: Accumulated reward:       2.27
# Episode 4308: Accumulated reward:       1.81
# Episode 4309: Accumulated reward:       2.29
# Episode 4310: Accumulated reward:       1.85
# Episode 4311: Accumulated reward:       1.41
# Episode 4312: Accumulated reward:       0.91
# Episode 4313: Accumulated reward:       0.33
# Episode 4314: Accumulated reward:       0.35
# Episode 4315: Accumulated reward:       0.96
# Episode 4316: Accumulated reward:       0.80
# Episode 4317: Accumulated reward:       0.46
# Episode 4318: Accumulated reward:       0.87
# Episode 4319: Accumulated reward:       0.24
# Episode 4320: Accumulated reward:       0.61
# Episode 4321: Accumulated reward:       0.94
# Episode 4322: Accumulated reward:       0.80
# Episode 4323: Accumulated reward:       0.86
# Episode 4324: Accumulated reward:       0.39
# Episode 4325: Accumulated reward:      -0.37
# Episode 4326: Accumulated reward:      -0.15
# Episode 4327: Accumulated reward:      -0.19
# Episode 4328: Accumulated reward:      -0.55
# Episode 4329: Accumulated reward:      -0.33
# Episode 4330: Accumulated reward:      -0.47
# Episode 4331: Accumulated reward:      -0.47
# Episode 4332: Accumulated reward:      -0.42
# Episode 4333: Accumulated reward:      -0.44
# Episode 4334: Accumulated reward:       0.18
# Episode 4335: Accumulated reward:       0.61
# Episode 4336: Accumulated reward:       0.57
# Episode 4337: Accumulated reward:       0.71
# Episode 4338: Accumulated reward:       1.21
# Episode 4339: Accumulated reward:       1.63
# Episode 4340: Accumulated reward:       1.83
# Episode 4341: Accumulated reward:       2.05
# Episode 4342: Accumulated reward:       2.25
# Episode 4343: Accumulated reward:       2.64
# Episode 4344: Accumulated reward:       2.42
# Episode 4345: Accumulated reward:       2.33
# Episode 4346: Accumulated reward:       2.27
# Episode 4347: Accumulated reward:       2.39
# Episode 4348: Accumulated reward:       2.49
# Episode 4349: Accumulated reward:       2.51
# Episode 4350: Accumulated reward:       2.66
# Episode 4351: Accumulated reward:       2.71
# Episode 4352: Accumulated reward:       2.84
# Episode 4353: Accumulated reward:       3.09
# Episode 4354: Accumulated reward:       2.80
# Episode 4355: Accumulated reward:       2.48
# Episode 4356: Accumulated reward:       2.87
# Episode 4357: Accumulated reward:       3.02
# Episode 4358: Accumulated reward:       3.25
# Episode 4359: Accumulated reward:       2.80
# Episode 4360: Accumulated reward:       2.56
# Episode 4361: Accumulated reward:       2.09
# Episode 4362: Accumulated reward:       1.67
# Episode 4363: Accumulated reward:       1.27
# Episode 4364: Accumulated reward:       1.07
# Episode 4365: Accumulated reward:       1.00
# Episode 4366: Accumulated reward:       0.41
# Episode 4367: Accumulated reward:       0.51
# Episode 4368: Accumulated reward:      -0.25
# Episode 4369: Accumulated reward:      -0.33
# Episode 4370: Accumulated reward:      -0.53
# Episode 4371: Accumulated reward:      -0.70
# Episode 4372: Accumulated reward:      -0.22
# Episode 4373: Accumulated reward:       0.27
# Episode 4374: Accumulated reward:       0.86
# Episode 4375: Accumulated reward:       1.44
# Episode 4376: Accumulated reward:       1.84
# Episode 4377: Accumulated reward:       1.81
# Episode 4378: Accumulated reward:       2.39
# Episode 4379: Accumulated reward:       2.63
# Episode 4380: Accumulated reward:       2.96
# Episode 4381: Accumulated reward:       3.54
# Episode 4382: Accumulated reward:       3.17
# Episode 4383: Accumulated reward:       2.93
# Episode 4384: Accumulated reward:       2.82
# Episode 4385: Accumulated reward:       2.66
# Episode 4386: Accumulated reward:       2.52
# Episode 4387: Accumulated reward:       2.45
# Episode 4388: Accumulated reward:       2.10
# Episode 4389: Accumulated reward:       2.34
# Episode 4390: Accumulated reward:       1.95
# Episode 4391: Accumulated reward:       1.54
# Episode 4392: Accumulated reward:       1.57
# Episode 4393: Accumulated reward:       1.07
# Episode 4394: Accumulated reward:       0.91
# Episode 4395: Accumulated reward:       1.10
# Episode 4396: Accumulated reward:       0.65
# Episode 4397: Accumulated reward:       0.73
# Episode 4398: Accumulated reward:       0.88
# Episode 4399: Accumulated reward:       0.94
# Episode 4400: Accumulated reward:       1.38
# Episode 4401: Accumulated reward:       1.67
# Episode 4402: Accumulated reward:       1.96
# Episode 4403: Accumulated reward:       2.54
# Episode 4404: Accumulated reward:       2.65
# Episode 4405: Accumulated reward:       2.62
# Episode 4406: Accumulated reward:       3.18
# Episode 4407: Accumulated reward:       2.64
# Episode 4408: Accumulated reward:       2.46
# Episode 4409: Accumulated reward:       2.04
# Episode 4410: Accumulated reward:       1.50
# Episode 4411: Accumulated reward:       1.50
# Episode 4412: Accumulated reward:       1.35
# Episode 4413: Accumulated reward:       1.01
# Episode 4414: Accumulated reward:       0.86
# Episode 4415: Accumulated reward:       0.51
# Episode 4416: Accumulated reward:      -0.06
# Episode 4417: Accumulated reward:      -0.22
# Episode 4418: Accumulated reward:       0.15
# Episode 4419: Accumulated reward:       0.14
# Episode 4420: Accumulated reward:       0.38
# Episode 4421: Accumulated reward:      -0.12
# Episode 4422: Accumulated reward:      -0.26
# Episode 4423: Accumulated reward:      -0.09
# Episode 4424: Accumulated reward:       0.08
# Episode 4425: Accumulated reward:       0.34
# Episode 4426: Accumulated reward:       0.71
# Episode 4427: Accumulated reward:       1.18
# Episode 4428: Accumulated reward:       1.12
# Episode 4429: Accumulated reward:       1.39
# Episode 4430: Accumulated reward:       1.57
# Episode 4431: Accumulated reward:       2.05
# Episode 4432: Accumulated reward:       2.04
# Episode 4433: Accumulated reward:       2.01
# Episode 4434: Accumulated reward:       1.65
# Episode 4435: Accumulated reward:       1.58
# Episode 4436: Accumulated reward:       1.42
# Episode 4437: Accumulated reward:       1.13
# Episode 4438: Accumulated reward:       0.56
# Episode 4439: Accumulated reward:       0.14
# Episode 4440: Accumulated reward:      -0.27
# Episode 4441: Accumulated reward:      -0.09
# Episode 4442: Accumulated reward:      -0.04
# Episode 4443: Accumulated reward:      -0.49
# Episode 4444: Accumulated reward:      -0.33
# Episode 4445: Accumulated reward:      -0.54
# Episode 4446: Accumulated reward:      -0.78
# Episode 4447: Accumulated reward:      -0.35
# Episode 4448: Accumulated reward:      -0.36
# Episode 4449: Accumulated reward:      -0.26
# Episode 4450: Accumulated reward:      -0.05
# Episode 4451: Accumulated reward:      -0.08
# Episode 4452: Accumulated reward:      -0.26
# Episode 4453: Accumulated reward:       0.25
# Episode 4454: Accumulated reward:       0.25
# Episode 4455: Accumulated reward:       0.07
# Episode 4456: Accumulated reward:       0.55
# Episode 4457: Accumulated reward:       0.69
# Episode 4458: Accumulated reward:       1.10
# Episode 4459: Accumulated reward:       1.55
# Episode 4460: Accumulated reward:       1.95
# Episode 4461: Accumulated reward:       2.08
# Episode 4462: Accumulated reward:       2.42
# Episode 4463: Accumulated reward:       2.52
# Episode 4464: Accumulated reward:       2.73
# Episode 4465: Accumulated reward:       3.17
# Episode 4466: Accumulated reward:       3.37
# Episode 4467: Accumulated reward:       3.49
# Episode 4468: Accumulated reward:       3.89
# Episode 4469: Accumulated reward:       3.95
# Episode 4470: Accumulated reward:       3.97
# Episode 4471: Accumulated reward:       3.43
# Episode 4472: Accumulated reward:       3.50
# Episode 4473: Accumulated reward:       3.53
# Episode 4474: Accumulated reward:       2.96
# Episode 4475: Accumulated reward:       2.75
# Episode 4476: Accumulated reward:       2.59
# Episode 4477: Accumulated reward:       2.15
# Episode 4478: Accumulated reward:       1.43
# Episode 4479: Accumulated reward:       0.87
# Episode 4480: Accumulated reward:       0.84
# Episode 4481: Accumulated reward:       1.16
# Episode 4482: Accumulated reward:       0.69
# Episode 4483: Accumulated reward:       0.17
# Episode 4484: Accumulated reward:       0.93
# Episode 4485: Accumulated reward:       1.07
# Episode 4486: Accumulated reward:       1.19
# Episode 4487: Accumulated reward:       1.67
# Episode 4488: Accumulated reward:       2.19
# Episode 4489: Accumulated reward:       2.69
# Episode 4490: Accumulated reward:       2.40
# Episode 4491: Accumulated reward:       2.14
# Episode 4492: Accumulated reward:       2.03
# Episode 4493: Accumulated reward:       2.25
# Episode 4494: Accumulated reward:       2.07
# Episode 4495: Accumulated reward:       2.39
# Episode 4496: Accumulated reward:       2.38
# Episode 4497: Accumulated reward:       2.08
# Episode 4498: Accumulated reward:       1.98
# Episode 4499: Accumulated reward:       1.94
# Episode 4500: Accumulated reward:       2.21
# ...
# Episode 8082: Accumulated reward:       0.13
# Episode 8083: Accumulated reward:      -0.12
# Episode 8084: Accumulated reward:      -0.48
# Episode 8085: Accumulated reward:      -0.88
# Episode 8086: Accumulated reward:      -1.19
# Episode 8087: Accumulated reward:      -1.21
# Episode 8088: Accumulated reward:      -1.54
# Episode 8089: Accumulated reward:      -1.03
# Episode 8090: Accumulated reward:      -0.96
# Episode 8091: Accumulated reward:      -0.56
# Episode 8092: Accumulated reward:      -0.21
# Episode 8093: Accumulated reward:      -0.46
# Episode 8094: Accumulated reward:      -0.19
# Episode 8095: Accumulated reward:      -0.32
# Episode 8096: Accumulated reward:       0.09
# Episode 8097: Accumulated reward:      -0.02
# Episode 8098: Accumulated reward:       0.51
# Episode 8099: Accumulated reward:       0.54
# Episode 8100: Accumulated reward:       1.11
# Episode 8101: Accumulated reward:       1.18
# Episode 8102: Accumulated reward:       1.61
# Episode 8103: Accumulated reward:       1.78
# Episode 8104: Accumulated reward:       2.04
# Episode 8105: Accumulated reward:       2.12
# Episode 8106: Accumulated reward:       1.74
# Episode 8107: Accumulated reward:       2.21
# Episode 8108: Accumulated reward:       2.08
# Episode 8109: Accumulated reward:       2.06
# Episode 8110: Accumulated reward:       2.04
# Episode 8111: Accumulated reward:       1.87
# Episode 8112: Accumulated reward:       1.49
# Episode 8113: Accumulated reward:       1.77
# Episode 8114: Accumulated reward:       1.75
# Episode 8115: Accumulated reward:       2.21
# Episode 8116: Accumulated reward:       2.61
# Episode 8117: Accumulated reward:       2.31
# Episode 8118: Accumulated reward:       2.13
# Episode 8119: Accumulated reward:       2.32
# Episode 8120: Accumulated reward:       1.71
# Episode 8121: Accumulated reward:       1.78
# Episode 8122: Accumulated reward:       1.81
# Episode 8123: Accumulated reward:       1.60
# Episode 8124: Accumulated reward:       1.36
# Episode 8125: Accumulated reward:       1.46
# Episode 8126: Accumulated reward:       1.52
# Episode 8127: Accumulated reward:       1.53
# Episode 8128: Accumulated reward:       1.63
# Episode 8129: Accumulated reward:       1.02
# Episode 8130: Accumulated reward:       1.54
# Episode 8131: Accumulated reward:       1.35
# Episode 8132: Accumulated reward:       1.52
# Episode 8133: Accumulated reward:       1.64
# Episode 8134: Accumulated reward:       1.88
# Episode 8135: Accumulated reward:       1.76
# Episode 8136: Accumulated reward:       1.80
# Episode 8137: Accumulated reward:       2.24
# Episode 8138: Accumulated reward:       2.47
# Episode 8139: Accumulated reward:       2.95
# Episode 8140: Accumulated reward:       2.88
# Episode 8141: Accumulated reward:       3.03
# Episode 8142: Accumulated reward:       3.03
# Episode 8143: Accumulated reward:       3.11
# Episode 8144: Accumulated reward:       2.94
# Episode 8145: Accumulated reward:       2.76
# Episode 8146: Accumulated reward:       2.59
# Episode 8147: Accumulated reward:       2.44
# Episode 8148: Accumulated reward:       2.11
# Episode 8149: Accumulated reward:       1.66
# Episode 8150: Accumulated reward:       1.50
# Episode 8151: Accumulated reward:       1.11
# Episode 8152: Accumulated reward:       1.00
# Episode 8153: Accumulated reward:       1.07
# Episode 8154: Accumulated reward:       1.09
# Episode 8155: Accumulated reward:       0.78
# Episode 8156: Accumulated reward:       0.46
# Episode 8157: Accumulated reward:       0.61
# Episode 8158: Accumulated reward:       0.42
# Episode 8159: Accumulated reward:       0.29
# Episode 8160: Accumulated reward:       0.10
# Episode 8161: Accumulated reward:      -0.02
# Episode 8162: Accumulated reward:      -0.30
# Episode 8163: Accumulated reward:      -0.68
# Episode 8164: Accumulated reward:      -0.84
# Episode 8165: Accumulated reward:      -0.48
# Episode 8166: Accumulated reward:      -0.04
# Episode 8167: Accumulated reward:      -0.34
# Episode 8168: Accumulated reward:       0.18
# Episode 8169: Accumulated reward:       0.76
# Episode 8170: Accumulated reward:       1.15
# Episode 8171: Accumulated reward:       1.33
# Episode 8172: Accumulated reward:       1.67
# Episode 8173: Accumulated reward:       1.54
# Episode 8174: Accumulated reward:       1.34
# Episode 8175: Accumulated reward:       1.15
# Episode 8176: Accumulated reward:       0.84
# Episode 8177: Accumulated reward:       0.81
# Episode 8178: Accumulated reward:       0.41
# Episode 8179: Accumulated reward:      -0.10
# Episode 8180: Accumulated reward:      -0.53
# Episode 8181: Accumulated reward:      -0.10
# Episode 8182: Accumulated reward:      -0.64
# Episode 8183: Accumulated reward:       0.05
# Episode 8184: Accumulated reward:       0.50
# Episode 8185: Accumulated reward:       0.84
# Episode 8186: Accumulated reward:       1.08
# Episode 8187: Accumulated reward:       1.45
# Episode 8188: Accumulated reward:       1.52
# Episode 8189: Accumulated reward:       1.64
# Episode 8190: Accumulated reward:       1.93
# Episode 8191: Accumulated reward:       1.54
# Episode 8192: Accumulated reward:       2.15
# Episode 8193: Accumulated reward:       2.05
# Episode 8194: Accumulated reward:       2.13
# Episode 8195: Accumulated reward:       2.05
# Episode 8196: Accumulated reward:       1.94
# Episode 8197: Accumulated reward:       1.31
# Episode 8198: Accumulated reward:       1.52
# Episode 8199: Accumulated reward:       1.74
# Episode 8200: Accumulated reward:       1.55
# Episode 8201: Accumulated reward:       1.60
# Episode 8202: Accumulated reward:       1.48
# Episode 8203: Accumulated reward:       1.11
# Episode 8204: Accumulated reward:       1.11
# Episode 8205: Accumulated reward:       1.24
# Episode 8206: Accumulated reward:       1.67
# Episode 8207: Accumulated reward:       2.14
# Episode 8208: Accumulated reward:       1.97
# Episode 8209: Accumulated reward:       2.02
# Episode 8210: Accumulated reward:       2.47
# Episode 8211: Accumulated reward:       2.56
# Episode 8212: Accumulated reward:       2.75
# Episode 8213: Accumulated reward:       3.02
# Episode 8214: Accumulated reward:       2.82
# Episode 8215: Accumulated reward:       2.72
# Episode 8216: Accumulated reward:       2.01
# Episode 8217: Accumulated reward:       1.52
# Episode 8218: Accumulated reward:       2.21
# Episode 8219: Accumulated reward:       1.79
# Episode 8220: Accumulated reward:       1.96
# Episode 8221: Accumulated reward:       2.03
# Episode 8222: Accumulated reward:       1.53
# Episode 8223: Accumulated reward:       1.19
# Episode 8224: Accumulated reward:       1.09
# Episode 8225: Accumulated reward:       0.82
# Episode 8226: Accumulated reward:       1.33
# Episode 8227: Accumulated reward:       1.28
# Episode 8228: Accumulated reward:       0.88
# Episode 8229: Accumulated reward:       0.97
# Episode 8230: Accumulated reward:       0.32
# Episode 8231: Accumulated reward:       0.13
# Episode 8232: Accumulated reward:      -0.07
# Episode 8233: Accumulated reward:      -0.06
# Episode 8234: Accumulated reward:      -0.27
# Episode 8235: Accumulated reward:      -0.24
# Episode 8236: Accumulated reward:      -0.87
# Episode 8237: Accumulated reward:      -0.38
# Episode 8238: Accumulated reward:      -0.82
# Episode 8239: Accumulated reward:      -0.61
# Episode 8240: Accumulated reward:      -0.11
# Episode 8241: Accumulated reward:       0.56
# Episode 8242: Accumulated reward:       1.39
# Episode 8243: Accumulated reward:       1.46
# Episode 8244: Accumulated reward:       1.79
# Episode 8245: Accumulated reward:       1.89
# Episode 8246: Accumulated reward:       2.21
# Episode 8247: Accumulated reward:       1.84
# Episode 8248: Accumulated reward:       2.02
# Episode 8249: Accumulated reward:       1.63
# Episode 8250: Accumulated reward:       1.18
# Episode 8251: Accumulated reward:       0.78
# Episode 8252: Accumulated reward:       0.55
# Episode 8253: Accumulated reward:       0.83
# Episode 8254: Accumulated reward:       0.85
# Episode 8255: Accumulated reward:       1.09
# Episode 8256: Accumulated reward:       1.02
# Episode 8257: Accumulated reward:       1.34
# Episode 8258: Accumulated reward:       1.03
# Episode 8259: Accumulated reward:       1.21
# Episode 8260: Accumulated reward:       1.18
# Episode 8261: Accumulated reward:       0.72
# Episode 8262: Accumulated reward:       0.44
# Episode 8263: Accumulated reward:       0.08
# Episode 8264: Accumulated reward:      -0.11
# Episode 8265: Accumulated reward:      -0.69
# Episode 8266: Accumulated reward:      -0.92
# Episode 8267: Accumulated reward:      -0.74
# Episode 8268: Accumulated reward:      -0.52
# Episode 8269: Accumulated reward:      -0.58
# Episode 8270: Accumulated reward:      -0.16
# Episode 8271: Accumulated reward:       0.41
# Episode 8272: Accumulated reward:       0.41
# Episode 8273: Accumulated reward:       0.89
# Episode 8274: Accumulated reward:       0.92
# Episode 8275: Accumulated reward:       1.63
# Episode 8276: Accumulated reward:       1.74
# Episode 8277: Accumulated reward:       1.69
# Episode 8278: Accumulated reward:       1.80
# Episode 8279: Accumulated reward:       1.86
# Episode 8280: Accumulated reward:       1.27
# Episode 8281: Accumulated reward:       0.83
# Episode 8282: Accumulated reward:       0.70
# Episode 8283: Accumulated reward:      -0.03
# Episode 8284: Accumulated reward:      -0.25
# Episode 8285: Accumulated reward:      -0.81
# Episode 8286: Accumulated reward:      -0.82
# Episode 8287: Accumulated reward:      -0.86
# Episode 8288: Accumulated reward:      -0.70
# Episode 8289: Accumulated reward:      -0.52
# Episode 8290: Accumulated reward:       0.06
# Episode 8291: Accumulated reward:       0.38
# Episode 8292: Accumulated reward:       0.69
# Episode 8293: Accumulated reward:       1.18
# Episode 8294: Accumulated reward:       1.87
# Episode 8295: Accumulated reward:       2.11
# Episode 8296: Accumulated reward:       2.05
# Episode 8297: Accumulated reward:       1.73
# Episode 8298: Accumulated reward:       1.27
# Episode 8299: Accumulated reward:       1.33
# Episode 8300: Accumulated reward:       1.39
# Episode 8301: Accumulated reward:       1.28
# Episode 8302: Accumulated reward:       0.89
# Episode 8303: Accumulated reward:       0.84
# Episode 8304: Accumulated reward:       0.66
# Episode 8305: Accumulated reward:       0.57
# Episode 8306: Accumulated reward:       1.01
# Episode 8307: Accumulated reward:       1.48
# Episode 8308: Accumulated reward:       1.98
# Episode 8309: Accumulated reward:       2.36
# Episode 8310: Accumulated reward:       2.19
# Episode 8311: Accumulated reward:       2.43
# Episode 8312: Accumulated reward:       2.82
# Episode 8313: Accumulated reward:       2.54
# Episode 8314: Accumulated reward:       2.21
# Episode 8315: Accumulated reward:       2.08
# Episode 8316: Accumulated reward:       2.17
# Episode 8317: Accumulated reward:       1.96
# Episode 8318: Accumulated reward:       1.55
# Episode 8319: Accumulated reward:       1.40
# Episode 8320: Accumulated reward:       1.66
# Episode 8321: Accumulated reward:       1.65
# Episode 8322: Accumulated reward:       1.68
# Episode 8323: Accumulated reward:       2.26
# Episode 8324: Accumulated reward:       2.55
# Episode 8325: Accumulated reward:       2.89
# Episode 8326: Accumulated reward:       3.00
# Episode 8327: Accumulated reward:       2.92
# Episode 8328: Accumulated reward:       3.42
# Episode 8329: Accumulated reward:       3.39
# Episode 8330: Accumulated reward:       2.68
# Episode 8331: Accumulated reward:       2.79
# Episode 8332: Accumulated reward:       2.81
# Episode 8333: Accumulated reward:       2.27
# Episode 8334: Accumulated reward:       1.70
# Episode 8335: Accumulated reward:       1.82
# Episode 8336: Accumulated reward:       1.15
# Episode 8337: Accumulated reward:       0.95
# Episode 8338: Accumulated reward:       0.35
# Episode 8339: Accumulated reward:      -0.26
# Episode 8340: Accumulated reward:       0.17
# Episode 8341: Accumulated reward:       0.08
# Episode 8342: Accumulated reward:      -0.30
# Episode 8343: Accumulated reward:      -0.38
# Episode 8344: Accumulated reward:      -0.33
# Episode 8345: Accumulated reward:      -0.66
# Episode 8346: Accumulated reward:      -0.22
# Episode 8347: Accumulated reward:      -0.15
# Episode 8348: Accumulated reward:       0.11
# Episode 8349: Accumulated reward:       0.09
# Episode 8350: Accumulated reward:       0.11
# Episode 8351: Accumulated reward:      -0.04
# Episode 8352: Accumulated reward:       0.31
# Episode 8353: Accumulated reward:       0.51
# Episode 8354: Accumulated reward:       0.72
# Episode 8355: Accumulated reward:       0.34
# Episode 8356: Accumulated reward:       0.04
# Episode 8357: Accumulated reward:      -0.03
# Episode 8358: Accumulated reward:      -0.15
# Episode 8359: Accumulated reward:       0.46
# Episode 8360: Accumulated reward:       0.49
# Episode 8361: Accumulated reward:       0.55
# Episode 8362: Accumulated reward:       0.70
# Episode 8363: Accumulated reward:       0.95
# Episode 8364: Accumulated reward:       0.95
# Episode 8365: Accumulated reward:       1.07
# Episode 8366: Accumulated reward:       0.84
# Episode 8367: Accumulated reward:       1.19
# Episode 8368: Accumulated reward:       1.41
# Episode 8369: Accumulated reward:       1.47
# Episode 8370: Accumulated reward:       1.41
# Episode 8371: Accumulated reward:       1.35
# Episode 8372: Accumulated reward:       1.32
# Episode 8373: Accumulated reward:       1.36
# Episode 8374: Accumulated reward:       1.79
# Episode 8375: Accumulated reward:       2.24
# Episode 8376: Accumulated reward:       2.80
# Episode 8377: Accumulated reward:       2.88
# Episode 8378: Accumulated reward:       2.93
# Episode 8379: Accumulated reward:       2.78
# Episode 8380: Accumulated reward:       2.62
# Episode 8381: Accumulated reward:       2.77
# Episode 8382: Accumulated reward:       2.77
# Episode 8383: Accumulated reward:       2.74
# Episode 8384: Accumulated reward:       2.52
# Episode 8385: Accumulated reward:       2.58
# Episode 8386: Accumulated reward:       2.54
# Episode 8387: Accumulated reward:       2.46
# Episode 8388: Accumulated reward:       2.49
# Episode 8389: Accumulated reward:       2.37
# Episode 8390: Accumulated reward:       2.21
# Episode 8391: Accumulated reward:       2.19
# Episode 8392: Accumulated reward:       1.93
# Episode 8393: Accumulated reward:       1.43
# Episode 8394: Accumulated reward:       1.46
# Episode 8395: Accumulated reward:       1.29
# Episode 8396: Accumulated reward:       1.38
# Episode 8397: Accumulated reward:       1.55
# Episode 8398: Accumulated reward:       1.48
# Episode 8399: Accumulated reward:       1.72
# Episode 8400: Accumulated reward:       1.85
# Episode 8401: Accumulated reward:       1.72
# Episode 8402: Accumulated reward:       1.63
# Episode 8403: Accumulated reward:       1.64
# Episode 8404: Accumulated reward:       1.37
# Episode 8405: Accumulated reward:       1.51
# Episode 8406: Accumulated reward:       1.27
# Episode 8407: Accumulated reward:       0.74
# Episode 8408: Accumulated reward:       0.36
# Episode 8409: Accumulated reward:       0.19
# Episode 8410: Accumulated reward:       0.24
# Episode 8411: Accumulated reward:      -0.19
# Episode 8412: Accumulated reward:       0.00
# Episode 8413: Accumulated reward:       0.61
# Episode 8414: Accumulated reward:       0.85
# Episode 8415: Accumulated reward:       1.10
# Episode 8416: Accumulated reward:       1.17
# Episode 8417: Accumulated reward:       1.17
# Episode 8418: Accumulated reward:       1.25
# Episode 8419: Accumulated reward:       0.82
# Episode 8420: Accumulated reward:       0.73
# Episode 8421: Accumulated reward:       1.30
# Episode 8422: Accumulated reward:       0.81
# Episode 8423: Accumulated reward:       0.21
# Episode 8424: Accumulated reward:      -0.05
# Episode 8425: Accumulated reward:      -0.91
# Episode 8426: Accumulated reward:      -0.84
# Episode 8427: Accumulated reward:      -0.76
# Episode 8428: Accumulated reward:      -0.31
# Episode 8429: Accumulated reward:       0.17
# Episode 8430: Accumulated reward:       0.29
# Episode 8431: Accumulated reward:       0.30
# Episode 8432: Accumulated reward:       0.38
# Episode 8433: Accumulated reward:       0.72
# Episode 8434: Accumulated reward:       0.99
# Episode 8435: Accumulated reward:       1.61
# Episode 8436: Accumulated reward:       1.70

# %%
v_dist, player_y, vel_y, h_dist = zip(*dists)
plt.hist(vel_y)
# plt.legend(['v_dist', 'y', 'vel_y', 'h_dist'])
# Out:
# (array([151571.,  96976.,  79559.,  68511.,  70569.,  54063.,  47957.,
#          42807.,  38364.,  44986.]),
#  array([-0.9 , -0.71, -0.52, -0.33, -0.14,  0.05,  0.24,  0.43,  0.62,
#          0.81,  1.  ]),
#  <BarContainer object of 10 artists>)

# %%
plot(training_rewards, epsilons)

# %%
(Q != 0).sum(), Q.size
# Out:
# (22, 28)

# %%
env = wrap_env(FlappyBirdDiscreteEnv(render_mode="rgb_array"))
simulate_using_Q(env, Q, max_steps=500)
